# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KotzMarsa/ztp/blob/master/lab2.ipynb)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-47944260-77ff-487d-b3fb-3a6e8f777ad8" name="files[]" multiple disabled />
#      <output id="result-47944260-77ff-487d-b3fb-3a6e8f777ad8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiki.txt to wiki (1).txt
# User uploaded file "wiki.txt" with length 2211698 bytes

# %%
import re
import csv
itemgetter = lambda x: (lambda arr: arr[x])

frequency = {}
with open('wiki.txt', 'r') as wiki:
  text = wiki.read()
#words = text.split()
words = [word.lower() for word in re.findall(r'(\b[A-Za-z][a-z]{0,30}\b)', text)]
 
for word in words:
  frequency[word] = frequency.get(word,0) + 1

for key, value in sorted(frequency.items(), key = itemgetter(1), reverse = True)[:100]:
  print('{}, {}'.format(key, value))
# Out:
# w, 19759
# i, 5704
# na, 4242
# z, 3927
# ur, 2222
# do, 2208
# roku, 1971
# jest, 1783
# od, 1714
# przez, 1290
# a, 1036
# zm, 989
# gmina, 937
# powiecie, 899
# to, 899
# polsce, 886
# we, 845
# oraz, 814
# o, 763
# gminie, 725
# regionie, 623
# km, 614
# polski, 588
# m, 587
# lub, 569
# r, 565
# po, 536
# latach, 507
# francji, 499
# jako, 454
# departamencie, 430
# miasto, 424
# jego, 416
# nie, 416
# miasta, 360
# rodziny, 360
# lutego, 359
# maja, 352
# marca, 347
# stycznia, 344
# listopada, 343
# lat, 343
# dla, 332
# pod, 326
# ang, 325
# kraju, 323
# lipca, 312
# pozycji, 307
# czerwca, 305
# przy, 305
# kwietnia, 301
# de, 298
# sierpnia, 292
# za, 288
# znajduje, 279
# prowincji, 269
# the, 261
# grupy, 260
# nad, 260
# obecnie, 258
# grudnia, 255
# odkryta, 254
# niem, 254
# n, 252
# ok, 249
# jej, 247
# hrabstwie, 243
# jak, 240
# stanie, 235
# nazwa, 234
# gatunek, 231
# ze, 229
# dystrykcie, 226
# anglii, 225
# p, 225
# j, 223
# tym, 221
# album, 216
# ...

# %%
import re
import csv
itemgetter = lambda x: (lambda arr: arr[x])

frequency = {}
with open('wiki.txt', 'r') as wiki:
  text = wiki.read()
#words = text.split()
words = [word.lower() for word in re.findall(r'(\b[A-Za-z][a-z]{0,30}\b)', text)]
 
for word in words:
  frequency[word] = frequency.get(word,0) + 1

  
with open('slownik.csv', 'w') as csvfile:
  writer = csv.writer(csvfile, delimiter=',')
  for key, value in sorted(frequency.items(), key = itemgetter(1), reverse = True):
    writer.writerow([key, value])

# %%
from google.colab import files
files.download('slownik.csv')

# %%
import csv
with open('slownik.csv', 'r') as csvfile:
     reader = csv.reader(csvfile, delimiter=',')
     for row in reader:
        print (', '.join(row))
# Out:
# w, 19759
# i, 5704
# na, 4242
# z, 3927
# ur, 2222
# do, 2208
# roku, 1971
# jest, 1783
# od, 1714
# przez, 1290
# a, 1036
# zm, 989
# gmina, 937
# powiecie, 899
# to, 899
# polsce, 886
# we, 845
# oraz, 814
# o, 763
# gminie, 725
# regionie, 623
# km, 614
# polski, 588
# m, 587
# lub, 569
# r, 565
# po, 536
# latach, 507
# francji, 499
# jako, 454
# departamencie, 430
# miasto, 424
# jego, 416
# nie, 416
# miasta, 360
# rodziny, 360
# lutego, 359
# maja, 352
# marca, 347
# stycznia, 344
# listopada, 343
# lat, 343
# dla, 332
# pod, 326
# ang, 325
# kraju, 323
# lipca, 312
# pozycji, 307
# czerwca, 305
# przy, 305
# kwietnia, 301
# de, 298
# sierpnia, 292
# za, 288
# znajduje, 279
# prowincji, 269
# the, 261
# grupy, 260
# nad, 260
# obecnie, 258
# grudnia, 255
# odkryta, 254
# niem, 254
# n, 252
# ok, 249
# jej, 247
# hrabstwie, 243
# jak, 240
# stanie, 235
# nazwa, 234
# gatunek, 231
# ze, 229
# dystrykcie, 226
# anglii, 225
# p, 225
# j, 223
# tym, 221
# album, 216
# ...
